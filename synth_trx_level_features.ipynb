# %%
# This file combines all different type of transactions in to a single data frame. 
# Then output a dictionary with cutomer ID's as keys and features as values. 

# All the categorical columns are converted to one hot encoding and and the 
# transaction data and time are converted to time delta absolute positional encoding and cyclical positional encoding for hour of the day, day of the week and day of the month

# The idea is to feed all of these transaction into a reccurrant model such as 
# RNN or GRU to automatically make features for each customer instead of hand crafting them.

# %%
import pandas as pd
from datetime import time
from collections import Counter
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import os

# %%
# Load data
path  = Path('processed_synth_dataset')

frac = 1
wire = pd.read_csv(path/'wire_s.csv', engine="pyarrow").sample(frac=frac)
ach = pd.read_csv(path/'ach_s.csv', engine="pyarrow").sample(frac=frac)
cheque = pd.read_csv(path/'cheque_s.csv', engine="pyarrow").sample(frac=frac)
card = pd.read_csv(path/'card_s.csv', engine="pyarrow").sample(frac=frac)

# %%
#making dictionary of all transactions
transactions = {
    'wire': wire,
    'ach': ach,
    'cheque': cheque,
    'card': card
    }

# %%
# # Drop all the transaction id columns since they are all unique and not useful
# transactions['wire'].drop(columns=['wire_id'], inplace=True)
# transactions['abm'].drop(columns=['abm_id'], inplace=True)
# transactions['cheque'].drop(columns=['cheque_id'], inplace=True)
# transactions['eft'].drop(columns=['eft_id'], inplace=True)
# transactions['emt'].drop(columns=['emt_id'], inplace=True)
# transactions['card'].drop(columns=['card_trxn_id'], inplace=True)

# %%
# Combine date and time columns into a single datetime column

def combine_date_and_time(df):
    df['transaction_datetime'] = pd.to_datetime(df['transaction_date'].astype(str) + ' ' + df['transaction_time'].astype(str))
    df.drop(columns=['transaction_date', 'transaction_time'], inplace=True)
    return df

# %%
# sort by date and time
def sort_by_date_time(df):
    df = df.sort_values(by='transaction_datetime')    
    return df

# %%
# Add a column for the transaction type since all the dataframes are going to be combined
def trx_type_col(df:pd.DataFrame, trx_type:str):
    df['trx_type'] = trx_type
    return df

# %%
# Combine all the dataframes into a single dataframe
def combine_df(df_dict:dict):
    df = pd.concat(df_dict.values(), axis= 0, ignore_index=True)
    return df

# %%
# Combine date and time columns, sort by date and time, and add a column for the transaction type
for trx_type, df in transactions.items():
    df = combine_date_and_time(df)
    # df = sort_by_date_time(df)
    df = trx_type_col(df, trx_type)   
    transactions[trx_type] = df

# %%
# Combine all the dataframes into a single dataframe
combined_df = combine_df(transactions)

# %%
combined_df1 = combine_df(transactions)

# %%
# add positional encoding and cyclic encoding for date and time features
earliest_time = combined_df['transaction_datetime'].min()
latest_time = combined_df['transaction_datetime'].max()

abs_pos_encoding = (combined_df['transaction_datetime'] - earliest_time).apply(lambda x: x.total_seconds()/(latest_time-earliest_time).total_seconds()) 
combined_df['abs_pos_encoding'] = abs_pos_encoding
minutes = combined_df['transaction_datetime'].dt.minute
hours = combined_df['transaction_datetime'].dt.hour
# days = combined_df['transaction_datetime'].dt.day
week_day = combined_df['transaction_datetime'].dt.dayofweek

combined_df['cyc_enc_minutes_sin'] = np.sin(2*np.pi*minutes/60)
combined_df['cyc_enc_minutes_cos'] = np.cos(2*np.pi*minutes/60)

combined_df['cyc_enc_hours_sin'] = np.sin(2*np.pi*hours/24)
combined_df['cyc_enc_hours_cos'] = np.cos(2*np.pi*hours/24)

# combined_df['cyc_enc_days_sin'] = np.sin(2*np.pi*days/31)
# combined_df['cyc_enc_days_cos'] = np.cos(2*np.pi*days/31)

combined_df['cyc_enc_weekday_sin'] = np.sin(2*np.pi*week_day/7)
combined_df['cyc_enc_weekday_cos'] = np.cos(2*np.pi*week_day/7)

combined_df.drop(columns=['transaction_datetime'], inplace=True)

# %%
#converting city number to binary format
max_binary_width = len(np.binary_repr(combined_df['city'].max()))
city_id_to_binary = [np.binary_repr(x, width=max_binary_width) for x in list(combined_df['city'])]
bin_col_names = [f'city_bin_{i}' for i in range(max_binary_width)]
binary_dict = {}    
for col_name in bin_col_names:
    binary_dict[col_name] = []
   
for bin_num in city_id_to_binary:
    for i, col_name in enumerate(bin_col_names):
        binary_dict[col_name].append(int(bin_num[i]))

combined_df = pd.concat([combined_df, pd.DataFrame(binary_dict)], axis=1)

# %%
combined_df.drop(columns=['city'], inplace=True)

# %%
# Convert categorical columns to categorical data type
cols = combined_df.columns
for col in cols:
    if col in ['debit_credit', 'trx_type', 'currency']:
        combined_df[col] = combined_df[col].astype('category')

# %%
# One hot encode categorical columns
combined_df_encoded = pd.get_dummies(
    combined_df,
    columns=['debit_credit', 'trx_type', 'currency'],  # Columns to encode
)

# %%
# Make a dictionary of all the unique customer ids and their transactions
# get all the unique customer ids
combined_df_encoded_copy = combined_df_encoded.copy()

combined_df_encoded_copy.sort_values(by=['customer_id'], inplace=True, ignore_index=True) 

customer_ids = combined_df_encoded_copy['customer_id'].unique()

cust_trx_dict = {}

start_idx = 0
curr_idx = 0
last_idx = None
for cust in tqdm(customer_ids):
    while cust == combined_df_encoded_copy['customer_id'][curr_idx]:
        curr_idx += 1
        if curr_idx == len(combined_df_encoded_copy):
            cust_trx_dict[cust] = combined_df_encoded_copy.iloc[start_idx:]
            break
    last_idx = curr_idx
    cust_trx_dict[cust] = combined_df_encoded_copy.iloc[start_idx:last_idx]
    start_idx = curr_idx
# Out:
# 100%|██████████| 467468/467468 [00:58<00:00, 7954.03it/s]

# %%
list(cust_trx_dict[list(cust_trx_dict.keys())[0]].columns)
# Out:
# ['customer_id',
#  'amount_cad',
#  'Is Laundering',
#  'abs_pos_encoding',
#  'cyc_enc_minutes_sin',
#  'cyc_enc_minutes_cos',
#  'cyc_enc_hours_sin',
#  'cyc_enc_hours_cos',
#  'cyc_enc_weekday_sin',
#  'cyc_enc_weekday_cos',
#  'city_bin_0',
#  'city_bin_1',
#  'city_bin_2',
#  'city_bin_3',
#  'city_bin_4',
#  'city_bin_5',
#  'city_bin_6',
#  'city_bin_7',
#  'city_bin_8',
#  'city_bin_9',
#  'city_bin_10',
#  'city_bin_11',
#  'city_bin_12',
#  'city_bin_13',
#  'city_bin_14',
#  'city_bin_15',
#  'city_bin_16',
#  'city_bin_17',
#  'city_bin_18',
#  'debit_credit_credit',
#  'debit_credit_debit',
#  'trx_type_ach',
#  'trx_type_card',
#  'trx_type_cheque',
#  'trx_type_wire',
#  'currency_Australian Dollar',
#  'currency_Bitcoin',
#  'currency_Brazil Real',
#  'currency_Canadian Dollar',
#  'currency_Euro',
#  'currency_Mexican Peso',
#  'currency_Ruble',
#  'currency_Rupee',
#  'currency_Saudi Riyal',
#  'currency_Shekel',
#  'currency_Swiss Franc',
#  'currency_UK Pound',
#  'currency_US Dollar',
#  'currency_Yen',
#  'currency_Yuan']

# %%
# Save the dictionary to a pickle file
# The dictionalry has customer id as keys and their transactions as values
with open('synth_trx_level_training_data_dict.pkl', 'wb') as f:
    pickle.dump(cust_trx_dict, f)

# %%
i = 0
for cust, trx in cust_trx_dict.items():
    display(cust_trx_dict[cust])
    i += 1
    if i>5:
        break
# Out:
#        customer_id    amount_cad  Is Laundering  abs_pos_encoding  \
# 0        10042B660  28236.661509              0          0.534713
# 1        10042B660    307.257162              0          0.272739
# 2        10042B660   4789.885107              0          0.504506
# 3        10042B660    936.771624              0          0.321303
# 4        10042B660   2823.624243              0          0.367365
# ...            ...           ...            ...               ...
# 130771   10042B660    276.187512              0          0.304740
# 130772   10042B660   2322.174543              0          0.585614
# 130773   10042B660   2235.006111              0          0.068842
# 130774   10042B660     45.722964              0          0.548773
# 130775   10042B660   2918.523960              0          0.000668
#
#         cyc_enc_minutes_sin  cyc_enc_minutes_cos  cyc_enc_hours_sin  \
# 0             -5.877853e-01        -8.090170e-01      -7.071068e-01
# 1             -3.090170e-01         9.510565e-01       1.224647e-16
# 2             -2.079117e-01        -9.781476e-01       7.071068e-01
# 3              8.090170e-01        -5.877853e-01       8.660254e-01
# 4             -1.000000e+00        -1.836970e-16       5.000000e-01
# ...                     ...                  ...                ...
# 130771        -9.945219e-01        -1.045285e-01       2.588190e-01
# 130772        -4.067366e-01         9.135455e-01      -9.659258e-01
# 130773         5.665539e-16        -1.000000e+00       7.071068e-01
# 130774         9.781476e-01         2.079117e-01       7.071068e-01
# 130775         9.945219e-01        -1.045285e-01       0.000000e+00
#
#         cyc_enc_hours_cos  cyc_enc_weekday_sin  cyc_enc_weekday_cos  ...  \
# 0                0.707107            -0.433884            -0.900969  ...
# 1               -1.000000             0.000000             1.000000  ...
# 2               -0.707107            -0.433884            -0.900969  ...
# 3               -0.500000             0.781831             0.623490  ...
# 4                0.866025             0.974928            -0.222521  ...
# ...                   ...                  ...                  ...  ...
# 130771           0.965926             0.781831             0.623490  ...
# 130772          -0.258819            -0.974928            -0.222521  ...
# 130773           0.707107            -0.433884            -0.900969  ...
# 130774           0.707107            -0.974928            -0.222521  ...
# 130775           1.000000             0.433884            -0.900969  ...
#
#         currency_Mexican Peso  currency_Ruble  currency_Rupee  \
# 0                       False           False           False
# 1                       False           False           False
# 2                       False           False           False
# 3                       False           False           False
# 4                       False           False           False
# ...                       ...             ...             ...
# 130771                  False           False           False
# 130772                  False           False           False
# 130773                  False           False           False
# 130774                  False           False           False
# 130775                  False           False           False
#
#         currency_Saudi Riyal  currency_Shekel  currency_Swiss Franc  \
# 0                      False            False                 False
# 1                      False            False                 False
# 2                      False            False                 False
# 3                      False            False                 False
# 4                      False            False                 False
# ...                      ...              ...                   ...
# 130771                 False            False                 False
# 130772                 False            False                 False
# 130773                 False            False                 False
# 130774                 False            False                 False
# 130775                 False            False                 False
#
#         currency_UK Pound  currency_US Dollar  currency_Yen  currency_Yuan
# 0                   False                True         False          False
# 1                   False                True         False          False
# 2                   False                True         False          False
# 3                   False                True         False          False
# 4                   False                True         False          False
# ...                   ...                 ...           ...            ...
# 130771              False                True         False          False
# 130772              False                True         False          False
# 130773              False                True         False          False
# 130774              False                True         False          False
# 130775              False                True         False          False
#
# [130776 rows x 50 columns]
#        customer_id    amount_cad  Is Laundering  abs_pos_encoding  \
# 130776   10042B6A8  1.069376e+04              0          0.304197
# 130777   10042B6A8  9.426615e+03              0          0.181575
# 130778   10042B6A8  7.039288e+01              0          0.152495
# 130779   10042B6A8  4.540739e+03              0          0.498206
# 130780   10042B6A8  1.836576e+03              0          0.098798
# ...            ...           ...            ...               ...
# 212554   10042B6A8  1.922747e+05              0          0.314336
# 212555   10042B6A8  3.344602e+02              0          0.359521
# 212556   10042B6A8  2.184330e+03              0          0.252336
# 212557   10042B6A8  9.564619e+02              0          0.325809
# 212558   10042B6A8  2.027791e+06              0          0.387058
#
#         cyc_enc_minutes_sin  cyc_enc_minutes_cos  cyc_enc_hours_sin  \
# 130776            -0.104528            -0.994522       2.588190e-01
# 130777            -0.207912            -0.978148       0.000000e+00
# 130778            -0.500000             0.866025       1.224647e-16
# 130779             0.104528             0.994522       9.659258e-01
# 130780             0.207912            -0.978148      -7.071068e-01
# ...                     ...                  ...                ...
# 212554            -0.406737            -0.913545       9.659258e-01
# 212555            -0.669131            -0.743145      -2.588190e-01
# 212556            -0.951057             0.309017       8.660254e-01
# 212557             0.809017             0.587785       5.000000e-01
# 212558            -0.669131            -0.743145       5.000000e-01
#
#         cyc_enc_hours_cos  cyc_enc_weekday_sin  cyc_enc_weekday_cos  ...  \
# 130776           0.965926             0.781831             0.623490  ...
# 130777           1.000000            -0.781831             0.623490  ...
# 130778          -1.000000            -0.974928            -0.222521  ...
# 130779          -0.258819            -0.433884            -0.900969  ...
# 130780          -0.707107            -0.433884            -0.900969  ...
# ...                   ...                  ...                  ...  ...
# 212554           0.258819             0.781831             0.623490  ...
# 212555           0.965926             0.781831             0.623490  ...
# 212556           0.500000             0.000000             1.000000  ...
# 212557          -0.866025             0.781831             0.623490  ...
# 212558          -0.866025             0.974928            -0.222521  ...
#
#         currency_Mexican Peso  currency_Ruble  currency_Rupee  \
# 130776                  False           False           False
# 130777                  False           False           False
# 130778                  False           False           False
# 130779                  False           False           False
# 130780                  False           False           False
# ...                       ...             ...             ...
# 212554                  False           False           False
# 212555                  False           False           False
# 212556                  False           False           False
# 212557                  False           False           False
# 212558                  False           False           False
#
#         currency_Saudi Riyal  currency_Shekel  currency_Swiss Franc  \
# 130776                 False            False                 False
# 130777                 False            False                 False
# 130778                 False            False                 False
# 130779                 False            False                 False
# 130780                 False            False                 False
# ...                      ...              ...                   ...
# 212554                 False            False                 False
# 212555                 False            False                 False
# 212556                 False            False                 False
# 212557                 False            False                 False
# 212558                 False            False                 False
#
#         currency_UK Pound  currency_US Dollar  currency_Yen  currency_Yuan
# 130776              False               False         False          False
# 130777              False               False         False          False
# 130778              False               False         False          False
# 130779              False               False         False          False
# 130780              False               False         False          False
# ...                   ...                 ...           ...            ...
# 212554              False               False         False          False
# 212555              False               False         False          False
# 212556              False               False         False          False
# 212557              False               False         False          False
# 212558              False               False         False          False
#
# [81783 rows x 50 columns]
#        customer_id    amount_cad  Is Laundering  abs_pos_encoding  \
# 212559   10042B6F0     44.264808              0          0.160047
# 212560   10042B6F0    548.101540              0          0.161090
# 212561   10042B6F0    593.266912              0          0.355766
# 212562   10042B6F0    339.248224              0          0.459321
# 212563   10042B6F0    411.448408              0          0.502587
# ...            ...           ...            ...               ...
# 237661   10042B6F0    448.174720              0          0.443049
# 237662   10042B6F0    233.192400              0          0.499917
# 237663   10042B6F0    165.210752              0          0.445427
# 237664   10042B6F0   4913.167056              0          0.372246
# 237665   10042B6F0  86453.593324              0          0.556367
#
#         cyc_enc_minutes_sin  cyc_enc_minutes_cos  cyc_enc_hours_sin  \
# 212559            -0.406737         9.135455e-01          -0.707107
# 212560             0.809017        -5.877853e-01          -0.866025
# 212561             0.669131         7.431448e-01          -0.500000
# 212562             0.104528        -9.945219e-01          -0.707107
# 212563            -0.994522         1.045285e-01           0.866025
# ...                     ...                  ...                ...
# 237661            -0.104528         9.945219e-01           0.866025
# 237662            -0.951057        -3.090170e-01           0.965926
# 237663            -0.406737         9.135455e-01           0.707107
# 237664            -0.951057        -3.090170e-01           0.866025
# 237665             1.000000         2.832769e-16           1.000000
#
#         cyc_enc_hours_cos  cyc_enc_weekday_sin  cyc_enc_weekday_cos  ...  \
# 212559      -7.071068e-01            -0.974928            -0.222521  ...
# 212560      -5.000000e-01            -0.974928            -0.222521  ...
# 212561       8.660254e-01             0.781831             0.623490  ...
# 212562      -7.071068e-01             0.433884            -0.900969  ...
# 212563      -5.000000e-01            -0.433884            -0.900969  ...
# ...                   ...                  ...                  ...  ...
# 237661      -5.000000e-01             0.433884            -0.900969  ...
# 237662      -2.588190e-01            -0.433884            -0.900969  ...
# 237663      -7.071068e-01             0.433884            -0.900969  ...
# 237664       5.000000e-01             0.974928            -0.222521  ...
# 237665       6.123234e-17            -0.974928            -0.222521  ...
#
#         currency_Mexican Peso  currency_Ruble  currency_Rupee  \
# 212559                  False           False           False
# 212560                  False           False           False
# 212561                  False           False           False
# 212562                  False           False           False
# 212563                  False           False           False
# ...                       ...             ...             ...
# 237661                  False           False           False
# 237662                  False           False           False
# 237663                  False           False           False
# 237664                  False           False           False
# 237665                  False           False           False
#
#         currency_Saudi Riyal  currency_Shekel  currency_Swiss Franc  \
# 212559                 False            False                 False
# 212560                 False            False                 False
# 212561                 False            False                 False
# 212562                 False            False                 False
# 212563                 False            False                 False
# ...                      ...              ...                   ...
# 237661                 False            False                 False
# 237662                 False            False                 False
# 237663                 False            False                 False
# 237664                 False            False                 False
# 237665                 False            False                 False
#
#         currency_UK Pound  currency_US Dollar  currency_Yen  currency_Yuan
# 212559              False               False         False           True
# 212560              False               False         False           True
# 212561              False               False         False           True
# 212562              False               False         False           True
# 212563              False               False         False           True
# ...                   ...                 ...           ...            ...
# 237661              False               False         False           True
# 237662              False               False         False           True
# 237663              False               False         False           True
# 237664              False               False         False           True
# 237665              False               False         False           True
#
# [25107 rows x 50 columns]
#        customer_id    amount_cad  Is Laundering  abs_pos_encoding  \
# 237666   10042B738   1527.497086              0          0.086741
# 237667   10042B738   1177.251206              0          0.037049
# 237668   10042B738  18607.150070              0          0.006467
# 237669   10042B738   3883.955450              0          0.090162
# 237670   10042B738    161.026230              0          0.174483
# ...            ...           ...            ...               ...
# 248239   10042B738    257.116790              0          0.381300
# 248240   10042B738   7054.025832              0          0.490863
# 248241   10042B738     99.109840              0          0.520903
# 248242   10042B738  24570.061314              0          0.098673
# 248243   10042B738  12481.744410              0          0.355265
#
#         cyc_enc_minutes_sin  cyc_enc_minutes_cos  cyc_enc_hours_sin  \
# 237666            -0.809017            -0.587785       5.000000e-01
# 237667            -0.951057             0.309017      -5.000000e-01
# 237668            -0.500000            -0.866025       5.000000e-01
# 237669             0.104528             0.994522       1.224647e-16
# 237670            -0.951057            -0.309017      -7.071068e-01
# ...                     ...                  ...                ...
# 248239             0.913545            -0.406737       8.660254e-01
# 248240             0.500000             0.866025       8.660254e-01
# 248241             0.500000             0.866025      -8.660254e-01
# 248242             0.500000            -0.866025      -7.071068e-01
# 248243            -0.500000             0.866025      -7.071068e-01
#
#         cyc_enc_hours_cos  cyc_enc_weekday_sin  cyc_enc_weekday_cos  ...  \
# 237666          -0.866025            -0.433884            -0.900969  ...
# 237667          -0.866025             0.433884            -0.900969  ...
# 237668           0.866025             0.433884            -0.900969  ...
# 237669          -1.000000            -0.433884            -0.900969  ...
# 237670           0.707107            -0.974928            -0.222521  ...
# ...                   ...                  ...                  ...  ...
# 248239          -0.500000             0.974928            -0.222521  ...
# 248240           0.500000            -0.433884            -0.900969  ...
# 248241          -0.500000            -0.433884            -0.900969  ...
# 248242          -0.707107            -0.433884            -0.900969  ...
# 248243           0.707107             0.781831             0.623490  ...
#
#         currency_Mexican Peso  currency_Ruble  currency_Rupee  \
# 237666                  False           False           False
# 237667                  False           False           False
# 237668                  False           False           False
# 237669                  False           False           False
# 237670                  False           False           False
# ...                       ...             ...             ...
# 248239                  False           False           False
# 248240                  False           False           False
# 248241                  False           False           False
# 248242                  False           False           False
# 248243                  False           False           False
#
#         currency_Saudi Riyal  currency_Shekel  currency_Swiss Franc  \
# 237666                 False            False                 False
# 237667                 False            False                 False
# 237668                 False            False                 False
# 237669                 False            False                 False
# 237670                 False            False                 False
# ...                      ...              ...                   ...
# 248239                 False            False                 False
# 248240                 False            False                 False
# 248241                 False            False                 False
# 248242                 False            False                 False
# 248243                 False            False                 False
#
#         currency_UK Pound  currency_US Dollar  currency_Yen  currency_Yuan
# 237666              False               False          True          False
# 237667              False               False          True          False
# 237668              False               False          True          False
# 237669              False               False          True          False
# 237670              False               False          True          False
# ...                   ...                 ...           ...            ...
# 248239              False               False          True          False
# 248240              False               False          True          False
# 248241              False               False          True          False
# 248242              False               False          True          False
# 248243              False               False          True          False
#
# [10578 rows x 50 columns]
#        customer_id    amount_cad  Is Laundering  abs_pos_encoding  \
# 248244   10042B780  3.188630e+02              0          0.136641
# 248245   10042B780  4.238710e+06              0          0.017356
# 248246   10042B780  1.349826e+03              0          0.084529
# 248247   10042B780  3.991546e+03              0          0.412258
# 248248   10042B780  7.227211e+03              0          0.274282
# ...            ...           ...            ...               ...
# 266146   10042B780  5.850470e+03              0          0.196262
# 266147   10042B780  2.538294e+03              0          0.311999
# 266148   10042B780  3.575871e+01              0          0.064252
# 266149   10042B780  1.122211e+07              0          0.048440
# 266150   10042B780  1.463757e+03              0          0.576560
#
#         cyc_enc_minutes_sin  cyc_enc_minutes_cos  cyc_enc_hours_sin  \
# 248244            -0.500000            -0.866025           1.000000
# 248245            -0.406737             0.913545           1.000000
# 248246            -0.994522             0.104528           0.707107
# 248247            -0.913545            -0.406737          -0.866025
# 248248            -0.406737            -0.913545          -0.258819
# ...                     ...                  ...                ...
# 266146             0.587785            -0.809017           1.000000
# 266147            -0.743145            -0.669131           0.866025
# 266148            -0.866025            -0.500000           0.258819
# 266149             0.809017            -0.587785          -0.965926
# 266150             0.913545            -0.406737          -0.500000
#
#         cyc_enc_hours_cos  cyc_enc_weekday_sin  cyc_enc_weekday_cos  ...  \
# 248244       6.123234e-17            -0.974928            -0.222521  ...
# 248245       6.123234e-17             0.433884            -0.900969  ...
# 248246      -7.071068e-01            -0.433884            -0.900969  ...
# 248247       5.000000e-01             0.974928            -0.222521  ...
# 248248      -9.659258e-01             0.000000             1.000000  ...
# ...                   ...                  ...                  ...  ...
# 266146       6.123234e-17            -0.781831             0.623490  ...
# 266147       5.000000e-01             0.781831             0.623490  ...
# 266148       9.659258e-01            -0.433884            -0.900969  ...
# 266149       2.588190e-01             0.433884            -0.900969  ...
# 266150      -8.660254e-01            -0.974928            -0.222521  ...
#
#         currency_Mexican Peso  currency_Ruble  currency_Rupee  \
# 248244                  False           False            True
# 248245                  False           False            True
# 248246                  False           False            True
# 248247                  False           False            True
# 248248                  False           False            True
# ...                       ...             ...             ...
# 266146                  False           False            True
# 266147                  False           False            True
# 266148                  False           False            True
# 266149                  False           False            True
# 266150                  False           False            True
#
#         currency_Saudi Riyal  currency_Shekel  currency_Swiss Franc  \
# 248244                 False            False                 False
# 248245                 False            False                 False
# 248246                 False            False                 False
# 248247                 False            False                 False
# 248248                 False            False                 False
# ...                      ...              ...                   ...
# 266146                 False            False                 False
# 266147                 False            False                 False
# 266148                 False            False                 False
# 266149                 False            False                 False
# 266150                 False            False                 False
#
#         currency_UK Pound  currency_US Dollar  currency_Yen  currency_Yuan
# 248244              False               False         False          False
# 248245              False               False         False          False
# 248246              False               False         False          False
# 248247              False               False         False          False
# 248248              False               False         False          False
# ...                   ...                 ...           ...            ...
# 266146              False               False         False          False
# 266147              False               False         False          False
# 266148              False               False         False          False
# 266149              False               False         False          False
# 266150              False               False         False          False
#
# [17907 rows x 50 columns]
#        customer_id    amount_cad  Is Laundering  abs_pos_encoding  \
# 266151   10042B7C8     40.138938              0          0.066672
# 266152   10042B7C8  32545.688280              0          0.522613
# 266153   10042B7C8   2317.651245              0          0.094334
# 266154   10042B7C8    106.381107              0          0.393650
# 266155   10042B7C8    235.102833              0          0.591121
# ...            ...           ...            ...               ...
# 270607   10042B7C8  28221.548628              0          0.108895
# 270608   10042B7C8   1618.060605              0          0.400617
# 270609   10042B7C8   7668.347757              0          0.096837
# 270610   10042B7C8  25529.240541              0          0.452603
# 270611   10042B7C8    981.642480              0          0.372497
#
#         cyc_enc_minutes_sin  cyc_enc_minutes_cos  cyc_enc_hours_sin  \
# 266151        -7.431448e-01        -6.691306e-01       5.000000e-01
# 266152        -9.945219e-01         1.045285e-01      -8.660254e-01
# 266153        -9.135455e-01        -4.067366e-01      -2.588190e-01
# 266154         1.000000e+00         2.832769e-16      -2.588190e-01
# 266155         7.431448e-01         6.691306e-01      -8.660254e-01
# ...                     ...                  ...                ...
# 270607         5.665539e-16        -1.000000e+00      -9.659258e-01
# 270608         2.079117e-01         9.781476e-01      -8.660254e-01
# 270609        -9.135455e-01        -4.067366e-01      -5.000000e-01
# 270610        -9.510565e-01         3.090170e-01       1.224647e-16
# 270611        -9.510565e-01         3.090170e-01       8.660254e-01
#
#         cyc_enc_hours_cos  cyc_enc_weekday_sin  cyc_enc_weekday_cos  ...  \
# 266151           0.866025            -0.433884            -0.900969  ...
# 266152          -0.500000            -0.433884            -0.900969  ...
# 266153          -0.965926            -0.433884            -0.900969  ...
# 266154          -0.965926             0.974928            -0.222521  ...
# 266155           0.500000            -0.974928            -0.222521  ...
# ...                   ...                  ...                  ...  ...
# 270607           0.258819            -0.433884            -0.900969  ...
# 270608          -0.500000             0.974928            -0.222521  ...
# 270609          -0.866025            -0.433884            -0.900969  ...
# 270610          -1.000000             0.433884            -0.900969  ...
# 270611           0.500000             0.974928            -0.222521  ...
#
#         currency_Mexican Peso  currency_Ruble  currency_Rupee  \
# 266151                  False            True           False
# 266152                  False            True           False
# 266153                  False            True           False
# 266154                  False            True           False
# 266155                  False            True           False
# ...                       ...             ...             ...
# 270607                  False            True           False
# 270608                  False            True           False
# 270609                  False            True           False
# 270610                  False            True           False
# 270611                  False            True           False
#
#         currency_Saudi Riyal  currency_Shekel  currency_Swiss Franc  \
# 266151                 False            False                 False
# 266152                 False            False                 False
# 266153                 False            False                 False
# 266154                 False            False                 False
# 266155                 False            False                 False
# ...                      ...              ...                   ...
# 270607                 False            False                 False
# 270608                 False            False                 False
# 270609                 False            False                 False
# 270610                 False            False                 False
# 270611                 False            False                 False
#
#         currency_UK Pound  currency_US Dollar  currency_Yen  currency_Yuan
# 266151              False               False         False          False
# 266152              False               False         False          False
# 266153              False               False         False          False
# 266154              False               False         False          False
# 266155              False               False         False          False
# ...                   ...                 ...           ...            ...
# 270607              False               False         False          False
# 270608              False               False         False          False
# 270609              False               False         False          False
# 270610              False               False         False          False
# 270611              False               False         False          False
#
# [4461 rows x 50 columns]

# %%
reloaded_data = pickle.load(open('synthetic_cust_trx_dict.pkl', 'rb'))

# %%
num_trx = 0
for value in reloaded_data.values():
    num_trx += len(value)
print(num_trx)
# Out:
# 5308695
