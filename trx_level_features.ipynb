# %%
# This file combines all different type of transactions in to a single data frame. 
# Then output a dictionary with cutomer ID's as keys and features as values. 

# All the categorical columns are converted to one hot encoding and and the 
# transaction data and time are converted to time delta absolute positional encoding and cyclical positional encoding for hour of the day, day of the week and day of the month

# The idea is to feed all of these transaction into a reccurrant model such as 
# RNN or GRU to automatically make features for each customer instead of hand crafting them.

# %%
import pandas as pd
from datetime import time
from collections import Counter
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import pickle

# %%
# Load data
frac = 1
wire = pd.read_csv('raw_data/wire.csv', engine="pyarrow")
abm = pd.read_csv('raw_data/abm.csv', engine="pyarrow")
cheque = pd.read_csv('raw_data/cheque.csv', engine="pyarrow").sample(frac = frac)
eft = pd.read_csv('raw_data/eft.csv', engine="pyarrow").sample(frac = frac)
emt = pd.read_csv('raw_data/emt.csv', engine="pyarrow").sample(frac = frac)
card = pd.read_csv('raw_data/card.csv', engine="pyarrow").sample(frac = frac)

# %%
# Preprocess data
# Make all amounts positive
card['amount_cad'] = np.abs(card['amount_cad'])
# Make debit and credit columns consistent across all dataframes
emt['debit_credit'] = emt['debit_credit'].apply(lambda x: 'debit' if x == 'D' else 'credit')

# %%
#making dictionary of all transactions
transactions = {
    'wire': wire,
    'abm': abm,
    'cheque': cheque,
    'eft': eft,
    'emt': emt,
    'card': card}

# %%
# Drop all the transaction id columns since they are all unique and not useful
transactions['wire'].drop(columns=['wire_id'], inplace=True)
transactions['abm'].drop(columns=['abm_id'], inplace=True)
transactions['cheque'].drop(columns=['cheque_id'], inplace=True)
transactions['eft'].drop(columns=['eft_id'], inplace=True)
transactions['emt'].drop(columns=['emt_id'], inplace=True)
transactions['card'].drop(columns=['card_trxn_id'], inplace=True)

# %%
# Combine date and time columns into a single datetime column

def combine_date_and_time(df):
    if 'transaction_time' not in df.columns:
        #rename the column transaction_date to transaction_datetime
        df['transaction_time'] = time(0, 0, 0)
        
    df['datetime_str'] = (
            df['transaction_date'].astype(str) + " " + df['transaction_time'].astype(str)
        )

    # Parse the combined string into datetime
    df['transaction_datetime'] = pd.to_datetime(
        df['datetime_str'],
        format='%Y-%m-%d %H:%M:%S',  # Adjust format to match your data
        errors='coerce'  # Coerce invalid values to NaT
    )
    df = df.drop(columns='datetime_str')
    df.drop(columns=['transaction_date', 'transaction_time'], inplace=True)
    
    return df

# %%
# sort by date and time
def sort_by_date_time(df):
    df = df.sort_values(by='transaction_datetime')    
    return df

# %%
# Add a column for the transaction type since all the dataframes are going to be combined
def trx_type_col(df:pd.DataFrame, trx_type:str):
    df['trx_type'] = trx_type
    return df

# %%
# Combine all the dataframes into a single dataframe
def combine_df(df_dict:dict):
    df = pd.concat(df_dict.values(), axis= 0, ignore_index=True)
    return df

# %%
# Combine date and time columns, sort by date and time, and add a column for the transaction type
for trx_type, df in transactions.items():
    df = combine_date_and_time(df)
    # df = sort_by_date_time(df)
    df = trx_type_col(df, trx_type)   
    transactions[trx_type] = df

# %%
# Combine all the dataframes into a single dataframe
combined_df = combine_df(transactions)

# %%
# add positional encoding and cyclic encoding for date and time features
earliest_time = combined_df['transaction_datetime'].min()
latest_time = combined_df['transaction_datetime'].max()

abs_pos_encoding = (combined_df['transaction_datetime'] - earliest_time).apply(lambda x: x.total_seconds()/(latest_time-earliest_time).total_seconds()) 
combined_df['abs_pos_encoding'] = abs_pos_encoding
hours = combined_df['transaction_datetime'].dt.hour
days = combined_df['transaction_datetime'].dt.day
week_day = combined_df['transaction_datetime'].dt.dayofweek

combined_df['cyc_enc_hours_sin'] = np.sin(2*np.pi*hours/24)
combined_df['cyc_enc_hours_cos'] = np.cos(2*np.pi*hours/24)

combined_df['cyc_enc_days_sin'] = np.sin(2*np.pi*days/31)
combined_df['cyc_enc_days_cos'] = np.cos(2*np.pi*days/31)

combined_df['cyc_enc_weekday_sin'] = np.sin(2*np.pi*week_day/7)
combined_df['cyc_enc_weekday_cos'] = np.cos(2*np.pi*week_day/7)

combined_df.drop(columns=['transaction_datetime'], inplace=True)

# %%
# Fill missing values with 'other' for categorical columns
cols = combined_df.columns
for col in cols:
    if col in ['cash_indicator', 'ecommerce_ind', 'merchant_category', 'country', 'city', 'province']:
       combined_df[col].fillna('other', inplace=True)
# Out:
# /var/folders/rv/m9l3_5yj5393fgp72c2hbr3w0000gn/T/ipykernel_54723/1762685878.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   combined_df[col].fillna('other', inplace=True)

# %%
# Convert categorical columns to categorical data type
for col in cols:
    if col in ['debit_credit','trx_type','cash_indicator', 'country', 'province', 'city','merchant_category', 'ecommerce_ind']:
        combined_df[col] = combined_df[col].astype('category')

# %%
# One hot encode categorical columns
combined_df_encoded = pd.get_dummies(
    combined_df,
    columns=['debit_credit','trx_type','cash_indicator', 'country', 'province', 'city','merchant_category', 'ecommerce_ind'],  # Columns to encode
)

# %%
# Make a dictionary of all the unique customer ids and their transactions
# get all the unique customer ids
combined_df_encoded_copy = combined_df_encoded.copy()

combined_df_encoded_copy.sort_values(by=['customer_id'], inplace=True, ignore_index=True) 

customer_ids = combined_df_encoded_copy['customer_id'].unique()

cust_trx_dict = {}

start_idx = 0
curr_idx = 0
last_idx = None
for cust in tqdm(customer_ids):
    while cust == combined_df_encoded_copy['customer_id'][curr_idx]:
        curr_idx += 1
        if curr_idx == len(combined_df_encoded_copy):
            cust_trx_dict[cust] = combined_df_encoded_copy.iloc[start_idx:]
            break
    last_idx = curr_idx
    cust_trx_dict[cust] = combined_df_encoded_copy.iloc[start_idx:last_idx]
    start_idx = curr_idx
# Out:
# 100%|██████████| 16226/16226 [00:03<00:00, 5166.67it/s]

# %%
list(cust_trx_dict[list(cust_trx_dict.keys())[0]].columns)
# Out:
# ['customer_id',
#  'amount_cad',
#  'abs_pos_encoding',
#  'cyc_enc_hours_sin',
#  'cyc_enc_hours_cos',
#  'cyc_enc_days_sin',
#  'cyc_enc_days_cos',
#  'cyc_enc_weekday_sin',
#  'cyc_enc_weekday_cos',
#  'debit_credit_credit',
#  'debit_credit_debit',
#  'trx_type_abm',
#  'trx_type_card',
#  'trx_type_cheque',
#  'trx_type_eft',
#  'trx_type_emt',
#  'trx_type_wire',
#  'cash_indicator_False',
#  'cash_indicator_True',
#  'cash_indicator_other',
#  'country_CA',
#  'country_GB',
#  'country_IE',
#  'country_SE',
#  'country_US',
#  'country_other',
#  'province_AB',
#  'province_AZ',
#  'province_BC',
#  'province_CA',
#  'province_DE',
#  'province_FL',
#  'province_GA',
#  'province_MA',
#  'province_MB',
#  'province_NB',
#  'province_NL',
#  'province_NS',
#  'province_NY',
#  'province_ON',
#  'province_PE',
#  'province_PQ',
#  'province_QC',
#  'province_SK',
#  'province_TX',
#  'province_WA',
#  'province_YT',
#  'province_other',
#  'city_ABBOTSFORD',
#  'city_AIRDRIE',
#  'city_AJAX',
#  'city_AMHERST',
#  'city_AURORA',
#  'city_BARRIE',
#  'city_BELLEVILLE',
#  'city_BOLTON',
#  'city_BOWMANVILLE',
#  'city_BRACEBRIDGE',
#  'city_BRADFORD',
#  'city_BRAMPTON',
#  'city_BRANDON',
#  'city_BRANTFORD',
#  'city_BROSSARD',
#  'city_BURLINGTON',
#  'city_BURNABY',
#  'city_CALGARY',
#  'city_CAMBRIDGE',
#  'city_CAMROSE',
#  'city_CANADA',
#  'city_CHARLOTTETOWN',
#  'city_CHATHAM',
#  'city_CHILLIWACK',
#  'city_COLEHARBOUR',
#  'city_COLLINGWOOD',
#  'city_CONCORD',
#  'city_COQUITLAM',
#  'city_CORNWALL',
#  'city_COTESTLUC',
#  'city_COURTENAY',
#  'city_DARTMOUTH',
#  'city_DELTA',
#  'city_DIGBY',
#  'city_DOWNSVIEW',
#  'city_DUNDAS',
#  'city_EDMONTON',
#  'city_EDSON',
#  'city_ETOBICOKE',
#  'city_FREDERICTON',
#  'city_GATINEAU',
#  'city_GLOUCESTER',
#  'city_GRANDE PRAI',
#  'city_GRANDE PRAIRI',
#  'city_GUELPH',
#  'city_HALIFAX',
#  'city_HALTONHLLS',
#  'city_HAMILTON',
#  'city_HAWKESBURY',
#  'city_HUNTSVILLE',
#  'city_KAMLOOPS',
#  'city_KANATA',
#  'city_KELOWNA',
#  'city_KESWICK',
#  'city_KINGSTON',
#  'city_KITCHENER',
#  'city_LANGFORD',
#  'city_LANGLEY',
#  'city_LAVAL',
#  'city_LEDUC',
#  'city_LETHBRIDGE',
#  'city_LINDSAY',
#  'city_LONDON',
#  'city_MAPLE',
#  'city_MAPLE RIDGE',
#  'city_MARKHAM',
#  'city_MARYSTOWN',
#  'city_MIDLAND',
#  'city_MILTON',
#  'city_MISSISSAUGA',
#  'city_MONCTON',
#  'city_MONTREAL',
#  'city_MOUNT PEARL',
#  'city_NANAIMO',
#  'city_NEPEAN',
#  'city_NEW MINAS',
#  'city_NEWMARKET',
#  'city_NIAGARA FAL',
#  'city_NIAGARA FLS',
#  'city_NORTH BAY',
#  'city_NORTH YORK',
#  'city_NORTHYORK',
#  'city_OAKVILLE',
#  'city_OKOTOKS',
#  'city_ORANGEVILLE',
#  'city_ORILLIA',
#  'city_ORLEANS',
#  'city_OSHAWA',
#  'city_OTTAWA',
#  'city_OWEN SOUND',
#  'city_OWENSOUND',
#  'city_PARRY SOUND',
#  'city_PEMBROKE',
#  'city_PETERBOROUG',
#  'city_PETERBOROUGH',
#  'city_PICKERING',
#  'city_PORT PERRY',
#  'city_PRINCE GEORGE',
#  'city_QUEBEC',
#  'city_RED DEER',
#  'city_REGINA',
#  'city_RICHMOND',
#  'city_RICHMOND HI',
#  'city_RICHMOND HILL',
#  'city_RICHMONDHILL',
#  'city_SAINT JOHN',
#  'city_SAINT-LAURENT',
#  'city_SAN FRANCISCO',
#  'city_SAN JOSE',
#  'city_SARNIA',
#  'city_SASKATOON',
#  'city_SCARBOROUGH',
#  'city_SEATTLE',
#  'city_SHERWOOD PARK',
#  'city_SLAVE LAKE',
#  'city_ST CATHARIN',
#  'city_ST CATHARINES',
#  'city_ST THOMAS',
#  "city_ST. JOHN'S",
#  'city_STCATHARINES',
#  'city_STJEROME',
#  'city_STJOHNS',
#  'city_STOCKHOLM',
#  'city_STRATFORD',
#  'city_STTHOMAS',
#  'city_SUDBURY',
#  'city_SURREY',
#  'city_THORNHILL',
#  'city_THUNDER BAY',
#  'city_TIMMINS',
#  'city_TORONTO',
#  'city_TRURO',
#  'city_VANCOUVER',
#  'city_VAUGHAN',
#  'city_VERDUN',
#  'city_VERNON',
#  'city_VICTORIA',
#  'city_WATERLOO',
#  'city_WELLAND',
#  'city_WESTHILL',
#  'city_WHITBY',
#  'city_WHITEHORSE',
#  'city_WINDSOR',
#  'city_WINNIPEG',
#  'city_WOODBRIDGE',
#  'city_WOODSTOCK',
#  'city_other',
#  'merchant_category_4121',
#  'merchant_category_4215',
#  'merchant_category_4722',
#  'merchant_category_4784',
#  'merchant_category_4812',
#  'merchant_category_4814',
#  'merchant_category_4816',
#  'merchant_category_4899',
#  'merchant_category_4900',
#  'merchant_category_5039',
#  'merchant_category_5045',
#  'merchant_category_5047',
#  'merchant_category_5085',
#  'merchant_category_5200',
#  'merchant_category_5211',
#  'merchant_category_5251',
#  'merchant_category_5300',
#  'merchant_category_5310',
#  'merchant_category_5311',
#  'merchant_category_5331',
#  'merchant_category_5411',
#  'merchant_category_5499',
#  'merchant_category_5511',
#  'merchant_category_5533',
#  'merchant_category_5541',
#  'merchant_category_5542',
#  'merchant_category_5651',
#  'merchant_category_5655',
#  'merchant_category_5691',
#  'merchant_category_5712',
#  'merchant_category_5732',
#  'merchant_category_5734',
#  'merchant_category_5812',
#  'merchant_category_5814',
#  'merchant_category_5815',
#  'merchant_category_5816',
#  'merchant_category_5817',
#  'merchant_category_5818',
#  'merchant_category_5912',
#  'merchant_category_5921',
#  'merchant_category_5941',
#  'merchant_category_5942',
#  'merchant_category_5943',
#  'merchant_category_5968',
#  'merchant_category_5999',
#  'merchant_category_6300',
#  'merchant_category_7011',
#  'merchant_category_7311',
#  'merchant_category_7372',
#  'merchant_category_7399',
#  'merchant_category_7523',
#  'merchant_category_7538',
#  'merchant_category_7542',
#  'merchant_category_8099',
#  'merchant_category_8398',
#  'merchant_category_8699',
#  'merchant_category_9399',
#  'merchant_category_other',
#  'ecommerce_ind_False',
#  'ecommerce_ind_True',
#  'ecommerce_ind_other']

# %%
# Save the dictionary to a pickle file
# The dictionalry has customer id as keys and their transactions as values
with open('cust_trx_dict.pkl', 'wb') as f:
    pickle.dump(cust_trx_dict, f)

# %%
i = 0
for cust, trx in cust_trx_dict.items():
    display(cust_trx_dict[cust])
    i += 1
    if i>5:
        break
# Out:
#         customer_id  amount_cad  abs_pos_encoding  cyc_enc_hours_sin  \
# 0  SYNCID0000000000     6316.04          0.184787                0.0
# 1  SYNCID0000000000        0.03          0.652188                0.0
# 2  SYNCID0000000000      415.24          0.076089                0.0
#
#    cyc_enc_hours_cos  cyc_enc_days_sin  cyc_enc_days_cos  cyc_enc_weekday_sin  \
# 0                1.0     -4.853020e-01         -0.874347            -0.433884
# 1                1.0     -2.449294e-16          1.000000            -0.974928
# 2                1.0      9.987165e-01         -0.050649             0.781831
#
#    cyc_enc_weekday_cos  debit_credit_credit  ...  merchant_category_7538  \
# 0            -0.900969                False  ...                   False
# 1            -0.222521                 True  ...                   False
# 2             0.623490                False  ...                   False
#
#    merchant_category_7542  merchant_category_8099  merchant_category_8398  \
# 0                   False                   False                   False
# 1                   False                   False                   False
# 2                   False                   False                   False
#
#    merchant_category_8699  merchant_category_9399  merchant_category_other  \
# 0                   False                   False                     True
# 1                   False                   False                     True
# 2                   False                   False                     True
#
#    ecommerce_ind_False  ecommerce_ind_True  ecommerce_ind_other
# 0                False               False                 True
# 1                False               False                 True
# 2                False               False                 True
#
# [3 rows x 256 columns]
#         customer_id  amount_cad  abs_pos_encoding  cyc_enc_hours_sin  \
# 3  SYNCID0000000001      213.40          0.221591           0.707107
# 4  SYNCID0000000001       60.30          0.540430          -0.965926
# 5  SYNCID0000000001        1.72          0.016976          -0.258819
# 6  SYNCID0000000001       15.97          0.309300           0.500000
#
#    cyc_enc_hours_cos  cyc_enc_days_sin  cyc_enc_days_cos  cyc_enc_weekday_sin  \
# 3          -0.707107         -0.897805         -0.440394             0.000000
# 4          -0.258819         -0.790776         -0.612106             0.781831
# 5          -0.965926          0.394356          0.918958             0.974928
# 6          -0.866025         -0.394356          0.918958             0.781831
#
#    cyc_enc_weekday_cos  debit_credit_credit  ...  merchant_category_7538  \
# 3             1.000000                False  ...                   False
# 4             0.623490                False  ...                   False
# 5            -0.222521                False  ...                   False
# 6             0.623490                False  ...                   False
#
#    merchant_category_7542  merchant_category_8099  merchant_category_8398  \
# 3                   False                   False                   False
# 4                   False                   False                   False
# 5                   False                   False                   False
# 6                   False                   False                   False
#
#    merchant_category_8699  merchant_category_9399  merchant_category_other  \
# 3                   False                   False                    False
# 4                   False                   False                     True
# 5                   False                   False                    False
# 6                   False                   False                     True
#
#    ecommerce_ind_False  ecommerce_ind_True  ecommerce_ind_other
# 3                 True               False                False
# 4                 True               False                False
# 5                False                True                False
# 6                 True               False                False
#
# [4 rows x 256 columns]
#          customer_id  amount_cad  abs_pos_encoding  cyc_enc_hours_sin  \
# 7   SYNCID0000000002     1597.38          0.163047                0.0
# 8   SYNCID0000000002     3771.60          0.260875                0.0
# 9   SYNCID0000000002     2186.16          0.097828                0.0
# 10  SYNCID0000000002     2506.00          0.250005                0.0
# 11  SYNCID0000000002     2503.42          0.141307                0.0
# 12  SYNCID0000000002     1661.76          0.913063                0.0
# 13  SYNCID0000000002     8137.34          0.380443                0.0
# 14  SYNCID0000000002     5296.11          0.717407                0.0
# 15  SYNCID0000000002     1127.94          0.065219                0.0
# 16  SYNCID0000000002     1283.80          0.945672                0.0
# 17  SYNCID0000000002      226.67          0.684797                0.0
# 18  SYNCID0000000002    77716.16          0.065219                0.0
# 19  SYNCID0000000002      573.46          0.826105                0.0
# 20  SYNCID0000000002      985.27          0.478271                0.0
# 21  SYNCID0000000002     2466.84          0.630448                0.0
# 22  SYNCID0000000002     6806.59          0.141307                0.0
# 23  SYNCID0000000002      564.95          0.826105                0.0
# 24  SYNCID0000000002     1069.74          0.000000                0.0
# 25  SYNCID0000000002      535.71          0.521750                0.0
# 26  SYNCID0000000002     1738.09          0.543490                0.0
# 27  SYNCID0000000002      321.30          0.684797                0.0
# 28  SYNCID0000000002      406.70          0.771756                0.0
# 29  SYNCID0000000002      434.57          0.141307                0.0
# 30  SYNCID0000000002     1740.28          0.260875                0.0
# 31  SYNCID0000000002     1609.53          0.380443                0.0
# 32  SYNCID0000000002     2937.80          0.826105                0.0
# 33  SYNCID0000000002    72621.39          0.521750                0.0
#
#     cyc_enc_hours_cos  cyc_enc_days_sin  cyc_enc_days_cos  \
# 7                 1.0         -0.101168         -0.994869
# 8                 1.0         -0.937752          0.347305
# 9                 1.0          0.897805         -0.440394
# 10                1.0         -0.988468          0.151428
# 11                1.0          0.299363         -0.954139
# 12                1.0         -0.988468          0.151428
# 13                1.0          0.937752          0.347305
# 14                1.0          0.937752          0.347305
# 15                1.0          0.988468          0.151428
# 16                1.0         -0.724793          0.688967
# 17                1.0          0.571268          0.820763
# 18                1.0          0.988468          0.151428
# 19                1.0         -0.101168         -0.994869
# 20                1.0          0.101168         -0.994869
# 21                1.0         -0.394356          0.918958
# 22                1.0          0.299363         -0.954139
# 23                1.0         -0.101168         -0.994869
# 24                1.0          0.201299          0.979530
# 25                1.0         -0.651372         -0.758758
# 26                1.0         -0.897805         -0.440394
# 27                1.0          0.571268          0.820763
# 28                1.0          0.790776         -0.612106
# 29                1.0          0.299363         -0.954139
# 30                1.0         -0.937752          0.347305
# 31                1.0          0.937752          0.347305
# 32                1.0         -0.101168         -0.994869
# 33                1.0         -0.651372         -0.758758
#
#     cyc_enc_weekday_sin  cyc_enc_weekday_cos  debit_credit_credit  ...  \
# 7              0.974928            -0.222521                 True  ...
# 8             -0.433884            -0.900969                False  ...
# 9              0.433884            -0.900969                 True  ...
# 10             0.433884            -0.900969                False  ...
# 11             0.000000             1.000000                 True  ...
# 12             0.781831             0.623490                 True  ...
# 13             0.781831             0.623490                False  ...
# 14            -0.433884            -0.900969                 True  ...
# 15             0.000000             1.000000                False  ...
# 16            -0.433884            -0.900969                 True  ...
# 17             0.781831             0.623490                 True  ...
# 18             0.000000             1.000000                 True  ...
# 19             0.000000             1.000000                False  ...
# 20             0.433884            -0.900969                 True  ...
# 21             0.433884            -0.900969                False  ...
# 22             0.000000             1.000000                False  ...
# 23             0.000000             1.000000                False  ...
# 24             0.781831             0.623490                 True  ...
# 25             0.000000             1.000000                False  ...
# 26             0.974928            -0.222521                False  ...
# 27             0.781831             0.623490                 True  ...
# 28             0.974928            -0.222521                False  ...
# 29             0.000000             1.000000                 True  ...
# 30            -0.433884            -0.900969                 True  ...
# 31             0.781831             0.623490                False  ...
# 32             0.000000             1.000000                False  ...
# 33             0.000000             1.000000                False  ...
#
#     merchant_category_7538  merchant_category_7542  merchant_category_8099  \
# 7                    False                   False                   False
# 8                    False                   False                   False
# 9                    False                   False                   False
# 10                   False                   False                   False
# 11                   False                   False                   False
# 12                   False                   False                   False
# 13                   False                   False                   False
# 14                   False                   False                   False
# 15                   False                   False                   False
# 16                   False                   False                   False
# 17                   False                   False                   False
# 18                   False                   False                   False
# 19                   False                   False                   False
# 20                   False                   False                   False
# 21                   False                   False                   False
# 22                   False                   False                   False
# 23                   False                   False                   False
# 24                   False                   False                   False
# 25                   False                   False                   False
# 26                   False                   False                   False
# 27                   False                   False                   False
# 28                   False                   False                   False
# 29                   False                   False                   False
# 30                   False                   False                   False
# 31                   False                   False                   False
# 32                   False                   False                   False
# 33                   False                   False                   False
#
#     merchant_category_8398  merchant_category_8699  merchant_category_9399  \
# 7                    False                   False                   False
# 8                    False                   False                   False
# 9                    False                   False                   False
# 10                   False                   False                   False
# 11                   False                   False                   False
# 12                   False                   False                   False
# 13                   False                   False                   False
# 14                   False                   False                   False
# 15                   False                   False                   False
# 16                   False                   False                   False
# 17                   False                   False                   False
# 18                   False                   False                   False
# 19                   False                   False                   False
# 20                   False                   False                   False
# 21                   False                   False                   False
# 22                   False                   False                   False
# 23                   False                   False                   False
# 24                   False                   False                   False
# 25                   False                   False                   False
# 26                   False                   False                   False
# 27                   False                   False                   False
# 28                   False                   False                   False
# 29                   False                   False                   False
# 30                   False                   False                   False
# 31                   False                   False                   False
# 32                   False                   False                   False
# 33                   False                   False                   False
#
#     merchant_category_other  ecommerce_ind_False  ecommerce_ind_True  \
# 7                      True                False               False
# 8                      True                False               False
# 9                      True                False               False
# 10                     True                False               False
# 11                     True                False               False
# 12                     True                False               False
# 13                     True                False               False
# 14                     True                False               False
# 15                     True                False               False
# 16                     True                False               False
# 17                     True                False               False
# 18                     True                False               False
# 19                     True                False               False
# 20                     True                False               False
# 21                     True                False               False
# 22                     True                False               False
# 23                     True                False               False
# 24                     True                False               False
# 25                     True                False               False
# 26                     True                False               False
# 27                     True                False               False
# 28                     True                False               False
# 29                     True                False               False
# 30                     True                False               False
# 31                     True                False               False
# 32                     True                False               False
# 33                     True                False               False
#
#     ecommerce_ind_other
# 7                  True
# 8                  True
# 9                  True
# 10                 True
# 11                 True
# 12                 True
# 13                 True
# 14                 True
# 15                 True
# 16                 True
# 17                 True
# 18                 True
# 19                 True
# 20                 True
# 21                 True
# 22                 True
# 23                 True
# 24                 True
# 25                 True
# 26                 True
# 27                 True
# 28                 True
# 29                 True
# 30                 True
# 31                 True
# 32                 True
# 33                 True
#
# [27 rows x 256 columns]
#          customer_id  amount_cad  abs_pos_encoding  cyc_enc_hours_sin  \
# 34  SYNCID0000000004      105.35          0.646265       5.000000e-01
# 35  SYNCID0000000004     1241.79          0.432060      -9.659258e-01
# 36  SYNCID0000000004        5.60          0.138979      -1.000000e+00
# 37  SYNCID0000000004       17.14          0.050599      -7.071068e-01
# 38  SYNCID0000000004       29.86          0.638435      -9.659258e-01
# 39  SYNCID0000000004      236.07          0.201238       1.224647e-16
# 40  SYNCID0000000004       19.85          0.083077      -7.071068e-01
# 41  SYNCID0000000004       53.44          0.962769      -2.588190e-01
# 42  SYNCID0000000004      118.32          0.299129       1.224647e-16
# 43  SYNCID0000000004       43.02          0.960046       9.659258e-01
# 44  SYNCID0000000004       87.30          0.308661       7.071068e-01
# 45  SYNCID0000000004       64.64          0.558707       7.071068e-01
# 46  SYNCID0000000004      178.50          0.766658       1.224647e-16
# 47  SYNCID0000000004      420.93          0.981986       8.660254e-01
# 48  SYNCID0000000004       21.69          0.376503      -7.071068e-01
# 49  SYNCID0000000004      107.15          0.704045      -1.000000e+00
# 50  SYNCID0000000004     1026.50          0.618672      -7.071068e-01
# 51  SYNCID0000000004       37.60          0.725990      -1.000000e+00
# 52  SYNCID0000000004       72.91          0.693413      -9.659258e-01
# 53  SYNCID0000000004      105.11          0.601230       9.659258e-01
# 54  SYNCID0000000004      182.91          0.754935       5.000000e-01
# 55  SYNCID0000000004     1043.27          0.757794      -9.659258e-01
# 56  SYNCID0000000004      154.25          0.127346      -9.659258e-01
# 57  SYNCID0000000004       52.99          0.473018       1.224647e-16
# 58  SYNCID0000000004       45.19          0.879609      -5.000000e-01
# 59  SYNCID0000000004       31.37          0.248322      -8.660254e-01
# 60  SYNCID0000000004        0.00          0.145682       7.071068e-01
# 61  SYNCID0000000004      475.07          0.246299      -7.071068e-01
# 62  SYNCID0000000004       44.09          0.559196       5.000000e-01
# 63  SYNCID0000000004      236.84          0.297797       7.071068e-01
# 64  SYNCID0000000004       82.49          0.093979      -7.071068e-01
# 65  SYNCID0000000004       97.55          0.302436      -9.659258e-01
# 66  SYNCID0000000004      422.96          0.407969       1.224647e-16
# 67  SYNCID0000000004      215.63          0.291378      -9.659258e-01
# 68  SYNCID0000000004       98.51          0.243999       5.000000e-01
# 69  SYNCID0000000004     9179.35          0.679693       1.224647e-16
# 70  SYNCID0000000004      137.42          0.345089      -9.659258e-01
# 71  SYNCID0000000004       24.79          0.333393      -8.660254e-01
# 72  SYNCID0000000004        2.01          0.621900       9.659258e-01
# 73  SYNCID0000000004      296.80          0.539435      -7.071068e-01
# 74  SYNCID0000000004        0.00          0.122821       9.659258e-01
# 75  SYNCID0000000004      162.50          0.768296      -8.660254e-01
# 76  SYNCID0000000004       35.04          0.236013      -9.659258e-01
# 77  SYNCID0000000004       73.16          0.047413       8.660254e-01
#
#     cyc_enc_hours_cos  cyc_enc_days_sin  cyc_enc_days_cos  \
# 34      -8.660254e-01         -0.201299          0.979530
# 35      -2.588190e-01          0.897805         -0.440394
# 36      -1.836970e-16          0.485302         -0.874347
# 37      -7.071068e-01          0.848644          0.528964
# 38      -2.588190e-01         -0.394356          0.918958
# 39      -1.000000e+00         -0.651372         -0.758758
# 40      -7.071068e-01          0.998717         -0.050649
# 41      -9.659258e-01         -0.571268          0.820763
# 42      -1.000000e+00         -0.571268          0.820763
# 43      -2.588190e-01         -0.571268          0.820763
# 44      -7.071068e-01         -0.394356          0.918958
# 45      -7.071068e-01         -0.968077         -0.250653
# 46      -1.000000e+00          0.897805         -0.440394
# 47      -5.000000e-01         -0.201299          0.979530
# 48      -7.071068e-01          0.848644          0.528964
# 49      -1.836970e-16          0.724793          0.688967
# 50       7.071068e-01         -0.724793          0.688967
# 51      -1.836970e-16          0.937752          0.347305
# 52       2.588190e-01          0.571268          0.820763
# 53      -2.588190e-01         -0.848644          0.528964
# 54      -8.660254e-01          0.968077         -0.250653
# 55      -2.588190e-01          0.968077         -0.250653
# 56      -2.588190e-01          0.651372         -0.758758
# 57      -1.000000e+00          0.299363         -0.954139
# 58       8.660254e-01         -0.790776         -0.612106
# 59       5.000000e-01         -0.998717         -0.050649
# 60      -7.071068e-01          0.299363         -0.954139
# 61      -7.071068e-01         -0.998717         -0.050649
# 62      -8.660254e-01         -0.968077         -0.250653
# 63      -7.071068e-01         -0.571268          0.820763
# 64      -7.071068e-01          0.968077         -0.250653
# 65       2.588190e-01         -0.571268          0.820763
# 66      -1.000000e+00          0.998717         -0.050649
# 67       2.588190e-01         -0.724793          0.688967
# 68      -8.660254e-01         -0.998717         -0.050649
# 69      -1.000000e+00          0.394356          0.918958
# 70      -2.588190e-01          0.394356          0.918958
# 71      -5.000000e-01          0.201299          0.979530
# 72       2.588190e-01         -0.571268          0.820763
# 73      -7.071068e-01         -0.790776         -0.612106
# 74      -2.588190e-01          0.651372         -0.758758
# 75      -5.000000e-01          0.897805         -0.440394
# 76      -2.588190e-01         -0.968077         -0.250653
# 77      -5.000000e-01          0.848644          0.528964
#
#     cyc_enc_weekday_sin  cyc_enc_weekday_cos  debit_credit_credit  ...  \
# 34            -0.433884            -0.900969                False  ...
# 35            -0.974928            -0.222521                False  ...
# 36            -0.781831             0.623490                False  ...
# 37            -0.974928            -0.222521                False  ...
# 38             0.433884            -0.900969                False  ...
# 39            -0.974928            -0.222521                 True  ...
# 40             0.781831             0.623490                False  ...
# 41            -0.974928            -0.222521                False  ...
# 42             0.000000             1.000000                False  ...
# 43            -0.974928            -0.222521                False  ...
# 44             0.781831             0.623490                False  ...
# 45             0.433884            -0.900969                False  ...
# 46             0.781831             0.623490                False  ...
# 47             0.000000             1.000000                False  ...
# 48             0.000000             1.000000                False  ...
# 49             0.974928            -0.222521                False  ...
# 50             0.781831             0.623490                False  ...
# 51            -0.433884            -0.900969                False  ...
# 52             0.781831             0.623490                False  ...
# 53             0.000000             1.000000                False  ...
# 54             0.000000             1.000000                False  ...
# 55             0.000000             1.000000                False  ...
# 56            -0.974928            -0.222521                False  ...
# 57             0.974928            -0.222521                False  ...
# 58            -0.433884            -0.900969                False  ...
# 59             0.974928            -0.222521                False  ...
# 60             0.000000             1.000000                False  ...
# 61             0.974928            -0.222521                False  ...
# 62             0.433884            -0.900969                False  ...
# 63             0.000000             1.000000                False  ...
# 64             0.974928            -0.222521                False  ...
# 65             0.000000             1.000000                False  ...
# 66             0.433884            -0.900969                False  ...
# 67            -0.781831             0.623490                False  ...
# 68             0.974928            -0.222521                False  ...
# 69             0.000000             1.000000                 True  ...
# 70            -0.433884            -0.900969                 True  ...
# 71             0.433884            -0.900969                False  ...
# 72             0.974928            -0.222521                False  ...
# 73             0.781831             0.623490                False  ...
# 74            -0.974928            -0.222521                False  ...
# 75             0.781831             0.623490                False  ...
# 76             0.781831             0.623490                False  ...
# 77            -0.974928            -0.222521                False  ...
#
#     merchant_category_7538  merchant_category_7542  merchant_category_8099  \
# 34                   False                   False                   False
# 35                   False                   False                   False
# 36                   False                   False                   False
# 37                   False                   False                   False
# 38                   False                   False                   False
# 39                   False                   False                   False
# 40                   False                   False                   False
# 41                   False                   False                   False
# 42                   False                   False                   False
# 43                   False                   False                   False
# 44                   False                   False                   False
# 45                   False                   False                   False
# 46                   False                   False                   False
# 47                   False                   False                   False
# 48                   False                   False                   False
# 49                   False                   False                   False
# 50                   False                   False                   False
# 51                   False                   False                   False
# 52                   False                   False                   False
# 53                   False                   False                   False
# 54                   False                   False                   False
# 55                   False                   False                   False
# 56                   False                   False                   False
# 57                   False                   False                   False
# 58                   False                   False                   False
# 59                   False                   False                   False
# 60                   False                   False                   False
# 61                   False                   False                   False
# 62                   False                   False                   False
# 63                   False                   False                   False
# 64                   False                   False                   False
# 65                   False                   False                   False
# 66                   False                   False                   False
# 67                   False                   False                   False
# 68                   False                   False                   False
# 69                   False                   False                   False
# 70                   False                   False                   False
# 71                   False                   False                   False
# 72                   False                   False                   False
# 73                   False                   False                   False
# 74                   False                   False                   False
# 75                   False                   False                   False
# 76                   False                   False                   False
# 77                   False                   False                   False
#
#     merchant_category_8398  merchant_category_8699  merchant_category_9399  \
# 34                   False                   False                   False
# 35                   False                   False                   False
# 36                   False                   False                   False
# 37                   False                   False                   False
# 38                   False                   False                   False
# 39                   False                   False                   False
# 40                   False                   False                   False
# 41                   False                   False                   False
# 42                   False                   False                   False
# 43                   False                   False                   False
# 44                   False                   False                   False
# 45                   False                   False                   False
# 46                   False                   False                   False
# 47                   False                   False                   False
# 48                   False                   False                   False
# 49                   False                   False                   False
# 50                   False                   False                   False
# 51                   False                   False                   False
# 52                   False                   False                   False
# 53                   False                   False                   False
# 54                   False                   False                   False
# 55                   False                   False                   False
# 56                   False                   False                   False
# 57                   False                   False                   False
# 58                   False                   False                   False
# 59                   False                   False                   False
# 60                   False                   False                   False
# 61                   False                   False                   False
# 62                   False                   False                   False
# 63                   False                   False                   False
# 64                   False                   False                   False
# 65                   False                   False                   False
# 66                   False                   False                   False
# 67                   False                   False                   False
# 68                   False                   False                   False
# 69                   False                   False                   False
# 70                   False                   False                   False
# 71                   False                   False                   False
# 72                   False                   False                   False
# 73                   False                   False                   False
# 74                   False                   False                   False
# 75                   False                   False                   False
# 76                   False                   False                   False
# 77                   False                   False                   False
#
#     merchant_category_other  ecommerce_ind_False  ecommerce_ind_True  \
# 34                    False                 True               False
# 35                    False                 True               False
# 36                    False                 True               False
# 37                    False                 True               False
# 38                    False                 True               False
# 39                    False                 True               False
# 40                    False                False                True
# 41                    False                 True               False
# 42                    False                 True               False
# 43                    False                 True               False
# 44                    False                 True               False
# 45                    False                 True               False
# 46                    False                 True               False
# 47                    False                 True               False
# 48                    False                 True               False
# 49                    False                 True               False
# 50                    False                False                True
# 51                    False                 True               False
# 52                    False                 True               False
# 53                    False                 True               False
# 54                    False                 True               False
# 55                    False                 True               False
# 56                    False                 True               False
# 57                    False                 True               False
# 58                    False                 True               False
# 59                    False                 True               False
# 60                    False                 True               False
# 61                    False                 True               False
# 62                    False                 True               False
# 63                    False                 True               False
# 64                     True                 True               False
# 65                    False                 True               False
# 66                     True                 True               False
# 67                     True                 True               False
# 68                    False                 True               False
# 69                     True                 True               False
# 70                    False                 True               False
# 71                    False                 True               False
# 72                    False                 True               False
# 73                     True                 True               False
# 74                    False                 True               False
# 75                    False                 True               False
# 76                    False                 True               False
# 77                    False                 True               False
#
#     ecommerce_ind_other
# 34                False
# 35                False
# 36                False
# 37                False
# 38                False
# 39                False
# 40                False
# 41                False
# 42                False
# 43                False
# 44                False
# 45                False
# 46                False
# 47                False
# 48                False
# 49                False
# 50                False
# 51                False
# 52                False
# 53                False
# 54                False
# 55                False
# 56                False
# 57                False
# 58                False
# 59                False
# 60                False
# 61                False
# 62                False
# 63                False
# 64                False
# 65                False
# 66                False
# 67                False
# 68                False
# 69                False
# 70                False
# 71                False
# 72                False
# 73                False
# 74                False
# 75                False
# 76                False
# 77                False
#
# [44 rows x 256 columns]
#           customer_id  amount_cad  abs_pos_encoding  cyc_enc_hours_sin  \
# 78   SYNCID0000000005        2.14          0.715711          -0.866025
# 79   SYNCID0000000005       22.12          0.094518          -0.866025
# 80   SYNCID0000000005       43.22          0.496710          -0.866025
# 81   SYNCID0000000005       84.70          0.178306           0.707107
# 82   SYNCID0000000005       82.05          0.873356           0.866025
# 83   SYNCID0000000005      852.50          0.794285           0.258819
# 84   SYNCID0000000005      148.33          0.192349          -0.866025
# 85   SYNCID0000000005       41.35          0.830490           0.707107
# 86   SYNCID0000000005       72.44          0.374837           0.258819
# 87   SYNCID0000000005       61.65          0.559351           0.258819
# 88   SYNCID0000000005       77.98          0.724224          -0.707107
# 89   SYNCID0000000005       27.33          0.224958          -0.866025
# 90   SYNCID0000000005       45.82          0.040313          -0.965926
# 91   SYNCID0000000005       52.22          0.243640           0.707107
# 92   SYNCID0000000005     2915.13          0.224958          -0.866025
# 93   SYNCID0000000005      214.68          0.319616           0.707107
# 94   SYNCID0000000005    28691.52          0.417436           0.707107
# 95   SYNCID0000000005       46.85          0.195132          -0.500000
# 96   SYNCID0000000005      224.59          0.954510          -0.965926
# 97   SYNCID0000000005      218.06          0.224958          -0.866025
# 98   SYNCID0000000005       26.78          0.148870          -0.866025
# 99   SYNCID0000000005     5648.82          0.991141           0.866025
# 100  SYNCID0000000005       45.85          0.178306           0.707107
# 101  SYNCID0000000005       79.99          0.042982          -0.500000
# 102  SYNCID0000000005     1066.93          0.480370           0.866025
# 103  SYNCID0000000005      285.25          0.094518          -0.866025
# 104  SYNCID0000000005     2186.53          0.004399           0.707107
# 105  SYNCID0000000005     1133.71          0.750760           0.258819
# 106  SYNCID0000000005    60607.55          0.863097           0.707107
# 107  SYNCID0000000005      104.52          0.909760          -0.866025
# 108  SYNCID0000000005     1194.36          0.254393           0.707107
# 109  SYNCID0000000005       59.51          0.069602           0.707107
# 110  SYNCID0000000005    32356.62          0.779316          -0.866025
# 111  SYNCID0000000005    15264.63          0.373956           0.707107
# 112  SYNCID0000000005        6.81          0.384834           0.707107
# 113  SYNCID0000000005       85.89          0.069602           0.707107
# 114  SYNCID0000000005     2317.57          0.485836          -0.866025
# 115  SYNCID0000000005     1298.56          0.319616           0.707107
# 116  SYNCID0000000005     4056.65          0.484622          -0.500000
# 117  SYNCID0000000005      200.90          0.170607          -0.866025
# 118  SYNCID0000000005       51.94          0.395703           0.707107
# 119  SYNCID0000000005       18.59          0.224958          -0.866025
# 120  SYNCID0000000005      336.52          0.189175           0.707107
# 121  SYNCID0000000005       35.15          0.997483          -1.000000
# 122  SYNCID0000000005       31.45          0.450046           0.707107
# 123  SYNCID0000000005     2443.79          0.154980           1.000000
# 124  SYNCID0000000005      256.46          0.877146          -0.866025
# 125  SYNCID0000000005       62.26          0.721795           0.707107
# 126  SYNCID0000000005        6.14          0.069250           0.866025
# 127  SYNCID0000000005       56.06          0.335778          -0.707107
#
#      cyc_enc_hours_cos  cyc_enc_days_sin  cyc_enc_days_cos  \
# 78        5.000000e-01      8.486443e-01          0.528964
# 79       -5.000000e-01      9.680771e-01         -0.250653
# 80       -5.000000e-01     -1.011683e-01         -0.994869
# 81       -7.071068e-01     -2.993631e-01         -0.954139
# 82       -5.000000e-01     -7.907757e-01         -0.612106
# 83        9.659258e-01      4.853020e-01         -0.874347
# 84       -5.000000e-01     -4.853020e-01         -0.874347
# 85       -7.071068e-01     -1.011683e-01         -0.994869
# 86       -9.659258e-01      8.486443e-01          0.528964
# 87       -9.659258e-01     -9.680771e-01         -0.250653
# 88       -7.071068e-01      9.377521e-01          0.347305
# 89       -5.000000e-01     -8.978045e-01         -0.440394
# 90       -2.588190e-01      7.247928e-01          0.688967
# 91       -7.071068e-01     -9.987165e-01         -0.050649
# 92       -5.000000e-01     -8.978045e-01         -0.440394
# 93       -7.071068e-01     -2.012985e-01          0.979530
# 94       -7.071068e-01      9.680771e-01         -0.250653
# 95        8.660254e-01     -4.853020e-01         -0.874347
# 96        2.588190e-01     -7.247928e-01          0.688967
# 97       -5.000000e-01     -8.978045e-01         -0.440394
# 98       -5.000000e-01      2.993631e-01         -0.954139
# 99        5.000000e-01     -2.449294e-16          1.000000
# 100      -7.071068e-01     -2.993631e-01         -0.954139
# 101       8.660254e-01      7.247928e-01          0.688967
# 102       5.000000e-01      1.011683e-01         -0.994869
# 103      -5.000000e-01      9.680771e-01         -0.250653
# 104      -7.071068e-01      2.012985e-01          0.979530
# 105       9.659258e-01      9.680771e-01         -0.250653
# 106      -7.071068e-01     -6.513725e-01         -0.758758
# 107      -5.000000e-01     -9.987165e-01         -0.050649
# 108      -7.071068e-01     -9.884683e-01          0.151428
# 109      -7.071068e-01      9.884683e-01          0.151428
# 110      -5.000000e-01      7.907757e-01         -0.612106
# 111      -7.071068e-01      8.486443e-01          0.528964
# 112      -7.071068e-01      9.377521e-01          0.347305
# 113      -7.071068e-01      9.884683e-01          0.151428
# 114      -5.000000e-01      1.011683e-01         -0.994869
# 115      -7.071068e-01     -2.012985e-01          0.979530
# 116      -8.660254e-01      1.011683e-01         -0.994869
# 117      -5.000000e-01     -1.011683e-01         -0.994869
# 118      -7.071068e-01      9.884683e-01          0.151428
# 119      -5.000000e-01     -8.978045e-01         -0.440394
# 120      -7.071068e-01     -4.853020e-01         -0.874347
# 121      -1.836970e-16     -2.449294e-16          1.000000
# 122      -7.071068e-01      6.513725e-01         -0.758758
# 123       6.123234e-17      1.011683e-01         -0.994869
# 124      -5.000000e-01     -7.907757e-01         -0.612106
# 125      -7.071068e-01      9.377521e-01          0.347305
# 126      -5.000000e-01      9.884683e-01          0.151428
# 127       7.071068e-01      2.012985e-01          0.979530
#
#      cyc_enc_weekday_sin  cyc_enc_weekday_cos  debit_credit_credit  ...  \
# 78              0.433884            -0.900969                 True  ...
# 79              0.974928            -0.222521                 True  ...
# 80             -0.433884            -0.900969                 True  ...
# 81              0.433884            -0.900969                 True  ...
# 82             -0.433884            -0.900969                 True  ...
# 83             -0.433884            -0.900969                 True  ...
# 84             -0.433884            -0.900969                 True  ...
# 85              0.000000             1.000000                 True  ...
# 86              0.000000             1.000000                 True  ...
# 87              0.433884            -0.900969                 True  ...
# 88             -0.433884            -0.900969                False  ...
# 89              0.000000             1.000000                 True  ...
# 90             -0.433884            -0.900969                False  ...
# 91              0.974928            -0.222521                 True  ...
# 92              0.000000             1.000000                 True  ...
# 93              0.974928            -0.222521                 True  ...
# 94             -0.433884            -0.900969                 True  ...
# 95             -0.433884            -0.900969                 True  ...
# 96             -0.433884            -0.900969                 True  ...
# 97              0.000000             1.000000                 True  ...
# 98              0.000000             1.000000                 True  ...
# 99              0.781831             0.623490                False  ...
# 100             0.433884            -0.900969                 True  ...
# 101            -0.433884            -0.900969                 True  ...
# 102             0.433884            -0.900969                False  ...
# 103             0.974928            -0.222521                 True  ...
# 104             0.781831             0.623490                False  ...
# 105             0.000000             1.000000                 True  ...
# 106             0.433884            -0.900969                False  ...
# 107             0.000000             1.000000                False  ...
# 108             0.433884            -0.900969                False  ...
# 109             0.000000             1.000000                 True  ...
# 110             0.974928            -0.222521                False  ...
# 111             0.000000             1.000000                False  ...
# 112             0.781831             0.623490                False  ...
# 113             0.000000             1.000000                 True  ...
# 114             0.433884            -0.900969                 True  ...
# 115             0.974928            -0.222521                 True  ...
# 116             0.433884            -0.900969                False  ...
# 117             0.974928            -0.222521                 True  ...
# 118             0.974928            -0.222521                 True  ...
# 119             0.000000             1.000000                 True  ...
# 120            -0.433884            -0.900969                False  ...
# 121             0.781831             0.623490                 True  ...
# 122             0.000000             1.000000                 True  ...
# 123             0.781831             0.623490                False  ...
# 124            -0.433884            -0.900969                 True  ...
# 125            -0.433884            -0.900969                 True  ...
# 126             0.000000             1.000000                 True  ...
# 127             0.433884            -0.900969                False  ...
#
#      merchant_category_7538  merchant_category_7542  merchant_category_8099  \
# 78                    False                   False                   False
# 79                    False                   False                   False
# 80                    False                   False                   False
# 81                    False                   False                   False
# 82                    False                   False                   False
# 83                    False                   False                   False
# 84                    False                   False                   False
# 85                    False                   False                   False
# 86                    False                   False                   False
# 87                    False                   False                   False
# 88                    False                   False                   False
# 89                    False                   False                   False
# 90                    False                   False                   False
# 91                    False                   False                   False
# 92                    False                   False                   False
# 93                    False                   False                   False
# 94                    False                   False                   False
# 95                    False                   False                   False
# 96                    False                   False                   False
# 97                    False                   False                   False
# 98                    False                   False                   False
# 99                    False                   False                   False
# 100                   False                   False                   False
# 101                   False                   False                   False
# 102                   False                   False                   False
# 103                   False                   False                   False
# 104                   False                   False                   False
# 105                   False                   False                   False
# 106                   False                   False                   False
# 107                   False                   False                   False
# 108                   False                   False                   False
# 109                   False                   False                   False
# 110                   False                   False                   False
# 111                   False                   False                   False
# 112                   False                   False                   False
# 113                   False                   False                   False
# 114                   False                   False                   False
# 115                   False                   False                   False
# 116                   False                   False                   False
# 117                   False                   False                   False
# 118                   False                   False                   False
# 119                   False                   False                   False
# 120                   False                   False                   False
# 121                   False                   False                   False
# 122                   False                   False                   False
# 123                   False                   False                   False
# 124                   False                   False                   False
# 125                   False                   False                   False
# 126                   False                   False                   False
# 127                   False                   False                   False
#
#      merchant_category_8398  merchant_category_8699  merchant_category_9399  \
# 78                    False                   False                   False
# 79                    False                   False                   False
# 80                    False                   False                   False
# 81                    False                   False                   False
# 82                    False                   False                   False
# 83                    False                   False                   False
# 84                    False                   False                   False
# 85                    False                   False                   False
# 86                    False                   False                   False
# 87                    False                   False                   False
# 88                    False                   False                   False
# 89                    False                   False                   False
# 90                    False                   False                   False
# 91                    False                   False                   False
# 92                    False                   False                   False
# 93                    False                   False                   False
# 94                    False                   False                   False
# 95                    False                   False                   False
# 96                    False                   False                   False
# 97                    False                   False                   False
# 98                    False                   False                   False
# 99                    False                   False                   False
# 100                   False                   False                   False
# 101                   False                   False                   False
# 102                   False                   False                   False
# 103                   False                   False                   False
# 104                   False                   False                   False
# 105                   False                   False                   False
# 106                   False                   False                   False
# 107                   False                   False                   False
# 108                   False                   False                   False
# 109                   False                   False                   False
# 110                   False                   False                   False
# 111                   False                   False                   False
# 112                   False                   False                   False
# 113                   False                   False                   False
# 114                   False                   False                   False
# 115                   False                   False                   False
# 116                   False                   False                   False
# 117                   False                   False                   False
# 118                   False                   False                   False
# 119                   False                   False                   False
# 120                   False                   False                   False
# 121                   False                   False                   False
# 122                   False                   False                   False
# 123                   False                   False                   False
# 124                   False                   False                   False
# 125                   False                   False                   False
# 126                   False                   False                   False
# 127                   False                   False                   False
#
#      merchant_category_other  ecommerce_ind_False  ecommerce_ind_True  \
# 78                      True                False               False
# 79                      True                False               False
# 80                      True                False               False
# 81                      True                False               False
# 82                      True                False               False
# 83                      True                False               False
# 84                      True                False               False
# 85                      True                False               False
# 86                      True                False               False
# 87                      True                False               False
# 88                      True                False               False
# 89                      True                False               False
# 90                      True                False               False
# 91                      True                False               False
# 92                      True                False               False
# 93                      True                False               False
# 94                      True                False               False
# 95                      True                False               False
# 96                      True                False               False
# 97                      True                False               False
# 98                      True                False               False
# 99                      True                False               False
# 100                     True                False               False
# 101                     True                False               False
# 102                     True                False               False
# 103                     True                False               False
# 104                     True                False               False
# 105                     True                False               False
# 106                     True                False               False
# 107                     True                False               False
# 108                     True                False               False
# 109                     True                False               False
# 110                     True                False               False
# 111                     True                False               False
# 112                     True                False               False
# 113                     True                False               False
# 114                     True                False               False
# 115                     True                False               False
# 116                     True                False               False
# 117                     True                False               False
# 118                     True                False               False
# 119                     True                False               False
# 120                     True                False               False
# 121                     True                False               False
# 122                     True                False               False
# 123                     True                False               False
# 124                     True                False               False
# 125                     True                False               False
# 126                     True                False               False
# 127                     True                False               False
#
#      ecommerce_ind_other
# 78                  True
# 79                  True
# 80                  True
# 81                  True
# 82                  True
# 83                  True
# 84                  True
# 85                  True
# 86                  True
# 87                  True
# 88                  True
# 89                  True
# 90                  True
# 91                  True
# 92                  True
# 93                  True
# 94                  True
# 95                  True
# 96                  True
# 97                  True
# 98                  True
# 99                  True
# 100                 True
# 101                 True
# 102                 True
# 103                 True
# 104                 True
# 105                 True
# 106                 True
# 107                 True
# 108                 True
# 109                 True
# 110                 True
# 111                 True
# 112                 True
# 113                 True
# 114                 True
# 115                 True
# 116                 True
# 117                 True
# 118                 True
# 119                 True
# 120                 True
# 121                 True
# 122                 True
# 123                 True
# 124                 True
# 125                 True
# 126                 True
# 127                 True
#
# [50 rows x 256 columns]
#           customer_id  amount_cad  abs_pos_encoding  cyc_enc_hours_sin  \
# 128  SYNCID0000000006     3071.24          0.771756                0.0
# 129  SYNCID0000000006     3047.98          0.315224                0.0
# 130  SYNCID0000000006   141466.98          0.413052                0.0
#
#      cyc_enc_hours_cos  cyc_enc_days_sin  cyc_enc_days_cos  \
# 128                1.0          0.790776         -0.612106
# 129                1.0         -0.201299          0.979530
# 130                1.0          0.968077         -0.250653
#
#      cyc_enc_weekday_sin  cyc_enc_weekday_cos  debit_credit_credit  ...  \
# 128             0.974928            -0.222521                False  ...
# 129             0.974928            -0.222521                False  ...
# 130            -0.433884            -0.900969                 True  ...
#
#      merchant_category_7538  merchant_category_7542  merchant_category_8099  \
# 128                   False                   False                   False
# 129                   False                   False                   False
# 130                   False                   False                   False
#
#      merchant_category_8398  merchant_category_8699  merchant_category_9399  \
# 128                   False                   False                   False
# 129                   False                   False                   False
# 130                   False                   False                   False
#
#      merchant_category_other  ecommerce_ind_False  ecommerce_ind_True  \
# 128                     True                False               False
# 129                     True                False               False
# 130                     True                False               False
#
#      ecommerce_ind_other
# 128                 True
# 129                 True
# 130                 True
#
# [3 rows x 256 columns]
